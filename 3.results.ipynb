# %%
import pandas as pd

# %%
df_results = pd.read_excel("correlations.xlsx")

# %%
df_results.groupby(["english","latin"]).std(numeric_only=True)["corr"].shape
# Out:
# (12633,)

# %%
df_results.groupby(["english","latin"]).std(numeric_only=True)["corr"].dropna().hist()
# Out:
# <AxesSubplot: >

# %%
#Agregate manuscripts
df_results['manuscript'] = df_results[['english','latin','manuscript']].groupby(['english','latin'])['manuscript'].transform(lambda x: ','.join(x))

# %%
df_std = df_results.groupby(["english","latin"]).std(numeric_only=True)["corr"].reset_index()
df_std.columns=["english","latin","std"]
df_final_results = df_results.merge(df_std,on=["english","latin"],how="left")
df_final_results = df_final_results.drop_duplicates(subset=["english","latin"],keep="first")
df_final_results = df_final_results.query("std<0.2 or std!=std")
df_final_results = df_final_results.query("corr>0.6").sort_values(by=["corr"],ascending=False)
df_final_results = df_final_results.fillna(0)

# %%
df_final_results.shape
# Out:
# (2228, 6)

# %%
df_final_results.sample(40)
# Out:
#              english          latin      corr  group         manuscript  \
# 10007         cennan          gigno  0.816329      1                  C
# 180            gefea        gaudium  0.749589      2  I,D,G,C,J,B,F,H,L
# 9930         smyryde           ungo  1.000000      1                  C
# 11655           abid        expecta  1.000000      1                J,B
# 160          geswinc          labor  0.768868      2  I,D,G,E,C,J,F,K,H
# 11133     ymbhwirfte      circuitus  0.638241      2                  J
# 15822      drygnesse      conuertam  0.632161      1                  K
# 5553           earþu        tristis  0.670216      2                  A
# 4566           iosep         ioseph  0.894244      2                  G
# 5205   wiþcwedenisse   contradictio  1.000000      2                  A
# 5245      geunrotsad      contristo  1.000000      2                  A
# 3601          lambra          agnus  1.000000      1                G,J
# 5522           weter           aqua  0.698579      2                A,E
# 5595       geblissad          laeto  0.621423      2                  A
# 6165       hneappade        dormiui  1.000000      1                  A
# 10065          flieh          volo2  0.730067      1                  C
# 948              pyt          fodio  0.816329      1                  I
# 829      frumwæstmas      primitiae  1.000000      1                  I
# 9294           hefyn          cęlum  0.749590      2                  C
# 5227          strene         sterno  1.000000      2                  A
# 292           wunung      habitatio  0.623765      2                I,F
# 2051          wacian         vigilo  0.816329      1        D,C,B,F,K,L
# 876          geneosa         uisita  1.000000      1                I,F
# 18252        sprecan         loquti  0.612258      2                  H
# 13306        wædlena         inopum  1.000000      1                  B
# 16736        gemyndi          memor  0.722693      2                  K
# 8293          hæbbæþ          habeo  0.821346      2                  E
# 3640            slat     interrumpo  1.000000      1              G,F,H
# 12535        ceaster        civitas  0.915868      2                  B
# 6096      þorhleoraþ  pertransibunt  1.000000      1                  A
# 2119           sares          surgo  0.632170      1              D,A,B
# 920      idumealande     alienigenę  0.816329      1                  I
# 12582          gehat           veto  0.844791      2                  B
# 15821           rece      nostraris  0.632161      1                  K
# 15782          undoþ        æternal  0.816324      1                  K
# 11727      earwodest        inebrio  0.816330      1                  J
# 16835         wæsmas        fructus  0.602128      2                  K
# 946    gelustfullode       delector  0.816329      1                  I
# 13322        ecelice          portæ  1.000000      1                  B
# 11730       gewendan  abhominabilis  0.816330      1                  J
#
#             std
# 10007  0.000000
# 180    0.104232
# 9930   0.000000
# 11655  0.036315
# 160    0.133683
# 11133  0.000000
# 15822  0.000000
# 5553   0.000000
# 4566   0.000000
# 5205   0.000000
# 5245   0.000000
# 3601   0.000000
# 5522   0.083873
# 5595   0.000000
# 6165   0.000000
# 10065  0.000000
# 948    0.000000
# 829    0.000000
# 9294   0.000000
# 5227   0.000000
# 292    0.058519
# 2051   0.100602
# 876    0.000000
# 18252  0.000000
# 13306  0.000000
# 16736  0.000000
# 8293   0.000000
# 3640   0.000000
# 12535  0.000000
# 6096   0.000000
# 2119   0.000007
# 920    0.000000
# 12582  0.000000
# 15821  0.000000
# 15782  0.000000
# 11727  0.000000
# 16835  0.000000
# 946    0.000000
# 13322  0.000000
# 11730  0.000000
